# %%
# 第一个cell - 导入库和设置
import sys
import os
sys.path.append('..')

import torch
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
# 第二个cell - 绘制训练曲线
# 暂时先没写，跳过，以后再补

# %%
# 第三个cell - 分析训练结果
# 这里也可以添加更多分析，比如学习率变化，梯度分析，模型复杂度分析等等
